# %%
import requests

# %%
import base64

# %%
import datetime

# %%
from urllib.parse import urlencode

# %%
client_id = '880e1efab91840d1839bc9e887302e4c'
client_secret = 'f0ea5f81740b48e288d8e9ea15489d63'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    token_url = "https://accounts.spotify.com/api/token"
    
    client_id = None
    client_secret = None
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
    
    def get_client_credentials(self):
        """
        returns a base64 encoded string
        
        """
        client_id = self.client_id
        client_secret = self.client_secret
        
        if client_id == None or client_secret == None:
            raise Exception("You must set client_id and client_secret")
        
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    
    
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization": f"Basic {client_creds_b64}"
        }
    
    def get_token_data(self):
        return {
    "grant_type": "client_credentials"
        }
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        
        
        r = requests.post(token_url, data = token_data, headers = token_headers)
        
        if r.status_code not in range(200, 299):
            return False

        now = datetime.datetime.now()

        data = r.json()
        access_token = data["access_token"]
        expires_in = data["expires_in"] #seconds

        expires = now + datetime.timedelta(seconds = expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True

# %%
client = SpotifyAPI(client_id, client_secret)

# %%
client.perform_auth()
# Out:
# True

# %%
access_token = client.access_token
access_token
# Out:
# 'BQDAZJLiIozFc84oVkhq5D3D1oJz3jbN_PRrFOlrP_syb0CY6ZqoxqkIUtu4M4HE76NzzTWVB-E9FFTTg6E'

# %%
headers = {
    "Authorization": f"Bearer {access_token}"
}
end_point = "https://api.spotify.com/v1/search"

data = urlencode({
    "q" : "BTS", "type" : "artist"
})

print(data)

lookup_url = f"{end_point}?{data}"
print(lookup_url)

r = requests.get(lookup_url, headers = headers)
print(r.status_code)
# Out:
# q=BTS&type=artist
# https://api.spotify.com/v1/search?q=BTS&type=artist
# 200

# %%
r.json()
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=BTS&type=artist&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#     'followers': {'href': None, 'total': 18576005},
#     'genres': ['k-pop', 'k-pop boy group'],
#     'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#     'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/0c9057cb30520f9f883a220051260fc66a2f3ffa',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/34ee854082d0ea4d571e2ecf7f4aecea61270ad0',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/156147697b696d4a6180e037dc1e2a33117d8d4a',
#       'width': 160}],
#     'name': 'BTS',
#     'popularity': 93,
#     'type': 'artist',
#     'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/51sg5jUqKu2tkbmPlwPrNH'},
#     'followers': {'href': None, 'total': 224589},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/51sg5jUqKu2tkbmPlwPrNH',
#     'id': '51sg5jUqKu2tkbmPlwPrNH',
#     'images': [],
#     'name': 'BTS World',
#     'popularity': 45,
#     'type': 'artist',
#     'uri': 'spotify:artist:51sg5jUqKu2tkbmPlwPrNH'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Dx8CcTQA8bWYen7zXsNW0'},
#     'followers': {'href': None, 'total': 171},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1Dx8CcTQA8bWYen7zXsNW0',
#     'id': '1Dx8CcTQA8bWYen7zXsNW0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ff015e6e8e0c4cbd4fde4dee',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ff015e6e8e0c4cbd4fde4dee',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ff015e6e8e0c4cbd4fde4dee',
#       'width': 64}],
#     'name': 'BTSC',
#     'popularity': 31,
#     'type': 'artist',
#     'uri': 'spotify:artist:1Dx8CcTQA8bWYen7zXsNW0'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3JsHnjpbhX4SnySpvpa9DK'},
#     'followers': {'href': None, 'total': 442087},
#     'genres': ['korean ost'],
#     'href': 'https://api.spotify.com/v1/artists/3JsHnjpbhX4SnySpvpa9DK',
#     'id': '3JsHnjpbhX4SnySpvpa9DK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27320af30dc4a6011fc11632211',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0220af30dc4a6011fc11632211',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485120af30dc4a6011fc11632211',
#       'width': 64}],
#     'name': 'V',
#     'popularity': 67,
#     'type': 'artist',
#     'uri': 'spotify:artist:3JsHnjpbhX4SnySpvpa9DK'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6b47NthIlcWFhQXGHmacUP'},
#     'followers': {'href': None, 'total': 30249},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6b47NthIlcWFhQXGHmacUP',
#     'id': '6b47NthIlcWFhQXGHmacUP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e513e7903f389ef98e868102',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e513e7903f389ef98e868102',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e513e7903f389ef98e868102',
#       'width': 64}],
#     'name': 'BTS',
#     'popularity': 16,
#     'type': 'artist',
#     'uri': 'spotify:artist:6b47NthIlcWFhQXGHmacUP'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3RThWxnHbyN5Hvkr66eYj7'},
#     'followers': {'href': None, 'total': 94629},
#     'genres': ['gqom', 'kwaito house', 'south african pop'],
#     'href': 'https://api.spotify.com/v1/artists/3RThWxnHbyN5Hvkr66eYj7',
#     'id': '3RThWxnHbyN5Hvkr66eYj7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e6d084a013c5e733fcddff06',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e6d084a013c5e733fcddff06',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e6d084a013c5e733fcddff06',
#       'width': 64}],
#     'name': 'Busiswa',
#     'popularity': 50,
#     'type': 'artist',
#     'uri': 'spotify:artist:3RThWxnHbyN5Hvkr66eYj7'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3YLl0gRlOoj3vRFuFDqYIt'},
#     'followers': {'href': None, 'total': 1059},
#     'genres': ['deep uplifting trance'],
#     'href': 'https://api.spotify.com/v1/artists/3YLl0gRlOoj3vRFuFDqYIt',
#     'id': '3YLl0gRlOoj3vRFuFDqYIt',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732b8c677df64839d2283e81ab',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022b8c677df64839d2283e81ab',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512b8c677df64839d2283e81ab',
#       'width': 64}],
#     'name': 'Btsound',
#     'popularity': 19,
#     'type': 'artist',
#     'uri': 'spotify:artist:3YLl0gRlOoj3vRFuFDqYIt'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3DFc7GdsVS5iBzHI9JuXUq'},
#     'followers': {'href': None, 'total': 3695},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3DFc7GdsVS5iBzHI9JuXUq',
#     'id': '3DFc7GdsVS5iBzHI9JuXUq',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273696efe5e88e8f867d9cd8b99',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02696efe5e88e8f867d9cd8b99',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851696efe5e88e8f867d9cd8b99',
#       'width': 64}],
#     'name': 'BTS',
#     'popularity': 5,
#     'type': 'artist',
#     'uri': 'spotify:artist:3DFc7GdsVS5iBzHI9JuXUq'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0REMZdsRCRQkOli7BxFUO2'},
#     'followers': {'href': None, 'total': 77},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0REMZdsRCRQkOli7BxFUO2',
#     'id': '0REMZdsRCRQkOli7BxFUO2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731b39584215d09409cb6917be',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021b39584215d09409cb6917be',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511b39584215d09409cb6917be',
#       'width': 64}],
#     'name': "BT's",
#     'popularity': 3,
#     'type': 'artist',
#     'uri': 'spotify:artist:0REMZdsRCRQkOli7BxFUO2'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/46SqMLtuMApmIOfROPpWSz'},
#     'followers': {'href': None, 'total': 10131},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/46SqMLtuMApmIOfROPpWSz',
#     'id': '46SqMLtuMApmIOfROPpWSz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27382a0ea4c05c78cb02bdf435c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0282a0ea4c05c78cb02bdf435c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485182a0ea4c05c78cb02bdf435c',
#       'width': 64}],
#     'name': 'Bts',
#     'popularity': 2,
#     'type': 'artist',
#     'uri': 'spotify:artist:46SqMLtuMApmIOfROPpWSz'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4D2oVKAzLwOxOlBHhapW0l'},
#     'followers': {'href': None, 'total': 14},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4D2oVKAzLwOxOlBHhapW0l',
#     'id': '4D2oVKAzLwOxOlBHhapW0l',
#     'images': [],
#     'name': 'Btsoicy',
#     'popularity': 1,
#     'type': 'artist',
#     'uri': 'spotify:artist:4D2oVKAzLwOxOlBHhapW0l'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2KchnUtnAh5D87EFsiuGXX'},
#     'followers': {'href': None, 'total': 18},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2KchnUtnAh5D87EFsiuGXX',
#     'id': '2KchnUtnAh5D87EFsiuGXX',
#     'images': [],
#     'name': 'BTS Mula',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:2KchnUtnAh5D87EFsiuGXX'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4DbjSClsQ5pXUSSYmL7MIv'},
#     'followers': {'href': None, 'total': 877},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4DbjSClsQ5pXUSSYmL7MIv',
#     'id': '4DbjSClsQ5pXUSSYmL7MIv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c2b7c23db89d15c3882fbcca',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c2b7c23db89d15c3882fbcca',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c2b7c23db89d15c3882fbcca',
#       'width': 64}],
#     'name': 'BTswing',
#     'popularity': 2,
#     'type': 'artist',
#     'uri': 'spotify:artist:4DbjSClsQ5pXUSSYmL7MIv'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7ivYaz5Cg1dKlWaS7GaTrR'},
#     'followers': {'href': None, 'total': 24},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7ivYaz5Cg1dKlWaS7GaTrR',
#     'id': '7ivYaz5Cg1dKlWaS7GaTrR',
#     'images': [],
#     'name': 'Btsn',
#     'popularity': 3,
#     'type': 'artist',
#     'uri': 'spotify:artist:7ivYaz5Cg1dKlWaS7GaTrR'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Vbo3Mfxsk7yREJclu7XZ4'},
#     'followers': {'href': None, 'total': 307},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4Vbo3Mfxsk7yREJclu7XZ4',
#     'id': '4Vbo3Mfxsk7yREJclu7XZ4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731dc920c58e3110a23ee5f210',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021dc920c58e3110a23ee5f210',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511dc920c58e3110a23ee5f210',
#       'width': 64}],
#     'name': 'BTSQD',
#     'popularity': 7,
#     'type': 'artist',
#     'uri': 'spotify:artist:4Vbo3Mfxsk7yREJclu7XZ4'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/26c5B9yK2GiYUe8H7zPYny'},
#     'followers': {'href': None, 'total': 492},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/26c5B9yK2GiYUe8H7zPYny',
#     'id': '26c5B9yK2GiYUe8H7zPYny',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/bc896db6fc6fbcbc4c2e1fbaa33ff8551073a760',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/b4b272f8ced064305d5b84b476cd4a953148bac9',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/c2f56735e154e1e5573720c0f5363c8fa9a2bcd9',
#       'width': 160}],
#     'name': 'BTS Exclusive',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:26c5B9yK2GiYUe8H7zPYny'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7q40cWpll2cnzzA8KDGtLW'},
#     'followers': {'href': None, 'total': 33},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7q40cWpll2cnzzA8KDGtLW',
#     'id': '7q40cWpll2cnzzA8KDGtLW',
#     'images': [],
#     'name': 'BTS Jocco',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:7q40cWpll2cnzzA8KDGtLW'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6flS6SGmhIuT5klqLyA18T'},
#     'followers': {'href': None, 'total': 399},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6flS6SGmhIuT5klqLyA18T',
#     'id': '6flS6SGmhIuT5klqLyA18T',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273dc1d7af518f26d536f5f98a8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02dc1d7af518f26d536f5f98a8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851dc1d7af518f26d536f5f98a8',
#       'width': 64}],
#     'name': 'BTS Chitlom',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:6flS6SGmhIuT5klqLyA18T'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/57SrOZy1twEVXI7KVaIxyE'},
#     'followers': {'href': None, 'total': 205},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/57SrOZy1twEVXI7KVaIxyE',
#     'id': '57SrOZy1twEVXI7KVaIxyE',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27378f710d03c67a35e15f24b4e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0278f710d03c67a35e15f24b4e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485178f710d03c67a35e15f24b4e',
#       'width': 64}],
#     'name': 'Big Time Sarah And The BTS Express',
#     'popularity': 2,
#     'type': 'artist',
#     'uri': 'spotify:artist:57SrOZy1twEVXI7KVaIxyE'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1K8CHRPSbXdLzRfOwmT2Ee'},
#     'followers': {'href': None, 'total': 81},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1K8CHRPSbXdLzRfOwmT2Ee',
#     'id': '1K8CHRPSbXdLzRfOwmT2Ee',
#     'images': [],
#     'name': 'BTS & ALXS',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:1K8CHRPSbXdLzRfOwmT2Ee'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=BTS&type=artist&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 65}}
