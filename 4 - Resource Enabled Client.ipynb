# %%
import requests

# %%
import base64

# %%
import datetime

# %%
import json

# %%
from urllib.parse import urlencode

# %%
client_id = '880e1efab91840d1839bc9e887302e4c'
client_secret = 'f0ea5f81740b48e288d8e9ea15489d63'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    token_url = "https://accounts.spotify.com/api/token"
    
    client_id = None
    client_secret = None
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
    
    def get_client_credentials(self):
        """
        returns a base64 encoded string
        
        """
        client_id = self.client_id
        client_secret = self.client_secret
        
        if client_id == None or client_secret == None:
            raise Exception("You must set client_id and client_secret")
        
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    
    
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization": f"Basic {client_creds_b64}"
        }
    
    def get_token_data(self):
        return {
    "grant_type": "client_credentials"
        }
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        
        
        r = requests.post(token_url, data = token_data, headers = token_headers)
        
        if r.status_code not in range(200, 299):
            raise Exception("Could not authenticate client")
            return False

        now = datetime.datetime.now()

        data = r.json()
        access_token = data["access_token"]
        expires_in = data["expires_in"] #seconds

        expires = now + datetime.timedelta(seconds = expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    
    def get_access_token(self):

        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token

    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}"
        }
        return headers
    
    def get_resource(self, lookup_id, resource_type='albums', version='v1'):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}/tracks"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()
    
    def get_album(self, _id):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type='artists')
    
    def search(self, query, search_type='artist' ): # type
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        data = urlencode({"q": query, "type": search_type.lower()})
        lookup_url = f"{endpoint}?{data}"
        r = requests.get(lookup_url, headers=headers)
        if r.status_code not in range(200, 299):  
            return {}
        return r.json()

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
spotify.search("BTS", search_type = "artist")
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=BTS&type=artist&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#     'followers': {'href': None, 'total': 18576005},
#     'genres': ['k-pop', 'k-pop boy group'],
#     'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#     'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/0c9057cb30520f9f883a220051260fc66a2f3ffa',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/34ee854082d0ea4d571e2ecf7f4aecea61270ad0',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/156147697b696d4a6180e037dc1e2a33117d8d4a',
#       'width': 160}],
#     'name': 'BTS',
#     'popularity': 93,
#     'type': 'artist',
#     'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/51sg5jUqKu2tkbmPlwPrNH'},
#     'followers': {'href': None, 'total': 224589},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/51sg5jUqKu2tkbmPlwPrNH',
#     'id': '51sg5jUqKu2tkbmPlwPrNH',
#     'images': [],
#     'name': 'BTS World',
#     'popularity': 45,
#     'type': 'artist',
#     'uri': 'spotify:artist:51sg5jUqKu2tkbmPlwPrNH'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Dx8CcTQA8bWYen7zXsNW0'},
#     'followers': {'href': None, 'total': 171},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1Dx8CcTQA8bWYen7zXsNW0',
#     'id': '1Dx8CcTQA8bWYen7zXsNW0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ff015e6e8e0c4cbd4fde4dee',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ff015e6e8e0c4cbd4fde4dee',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ff015e6e8e0c4cbd4fde4dee',
#       'width': 64}],
#     'name': 'BTSC',
#     'popularity': 31,
#     'type': 'artist',
#     'uri': 'spotify:artist:1Dx8CcTQA8bWYen7zXsNW0'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3JsHnjpbhX4SnySpvpa9DK'},
#     'followers': {'href': None, 'total': 442087},
#     'genres': ['korean ost'],
#     'href': 'https://api.spotify.com/v1/artists/3JsHnjpbhX4SnySpvpa9DK',
#     'id': '3JsHnjpbhX4SnySpvpa9DK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27320af30dc4a6011fc11632211',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0220af30dc4a6011fc11632211',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485120af30dc4a6011fc11632211',
#       'width': 64}],
#     'name': 'V',
#     'popularity': 67,
#     'type': 'artist',
#     'uri': 'spotify:artist:3JsHnjpbhX4SnySpvpa9DK'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6b47NthIlcWFhQXGHmacUP'},
#     'followers': {'href': None, 'total': 30249},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6b47NthIlcWFhQXGHmacUP',
#     'id': '6b47NthIlcWFhQXGHmacUP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e513e7903f389ef98e868102',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e513e7903f389ef98e868102',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e513e7903f389ef98e868102',
#       'width': 64}],
#     'name': 'BTS',
#     'popularity': 16,
#     'type': 'artist',
#     'uri': 'spotify:artist:6b47NthIlcWFhQXGHmacUP'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3RThWxnHbyN5Hvkr66eYj7'},
#     'followers': {'href': None, 'total': 94629},
#     'genres': ['gqom', 'kwaito house', 'south african pop'],
#     'href': 'https://api.spotify.com/v1/artists/3RThWxnHbyN5Hvkr66eYj7',
#     'id': '3RThWxnHbyN5Hvkr66eYj7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e6d084a013c5e733fcddff06',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e6d084a013c5e733fcddff06',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e6d084a013c5e733fcddff06',
#       'width': 64}],
#     'name': 'Busiswa',
#     'popularity': 50,
#     'type': 'artist',
#     'uri': 'spotify:artist:3RThWxnHbyN5Hvkr66eYj7'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3YLl0gRlOoj3vRFuFDqYIt'},
#     'followers': {'href': None, 'total': 1059},
#     'genres': ['deep uplifting trance'],
#     'href': 'https://api.spotify.com/v1/artists/3YLl0gRlOoj3vRFuFDqYIt',
#     'id': '3YLl0gRlOoj3vRFuFDqYIt',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732b8c677df64839d2283e81ab',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022b8c677df64839d2283e81ab',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512b8c677df64839d2283e81ab',
#       'width': 64}],
#     'name': 'Btsound',
#     'popularity': 19,
#     'type': 'artist',
#     'uri': 'spotify:artist:3YLl0gRlOoj3vRFuFDqYIt'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3DFc7GdsVS5iBzHI9JuXUq'},
#     'followers': {'href': None, 'total': 3695},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3DFc7GdsVS5iBzHI9JuXUq',
#     'id': '3DFc7GdsVS5iBzHI9JuXUq',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273696efe5e88e8f867d9cd8b99',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02696efe5e88e8f867d9cd8b99',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851696efe5e88e8f867d9cd8b99',
#       'width': 64}],
#     'name': 'BTS',
#     'popularity': 5,
#     'type': 'artist',
#     'uri': 'spotify:artist:3DFc7GdsVS5iBzHI9JuXUq'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0REMZdsRCRQkOli7BxFUO2'},
#     'followers': {'href': None, 'total': 77},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0REMZdsRCRQkOli7BxFUO2',
#     'id': '0REMZdsRCRQkOli7BxFUO2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731b39584215d09409cb6917be',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021b39584215d09409cb6917be',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511b39584215d09409cb6917be',
#       'width': 64}],
#     'name': "BT's",
#     'popularity': 3,
#     'type': 'artist',
#     'uri': 'spotify:artist:0REMZdsRCRQkOli7BxFUO2'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/46SqMLtuMApmIOfROPpWSz'},
#     'followers': {'href': None, 'total': 10131},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/46SqMLtuMApmIOfROPpWSz',
#     'id': '46SqMLtuMApmIOfROPpWSz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27382a0ea4c05c78cb02bdf435c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0282a0ea4c05c78cb02bdf435c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485182a0ea4c05c78cb02bdf435c',
#       'width': 64}],
#     'name': 'Bts',
#     'popularity': 2,
#     'type': 'artist',
#     'uri': 'spotify:artist:46SqMLtuMApmIOfROPpWSz'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4D2oVKAzLwOxOlBHhapW0l'},
#     'followers': {'href': None, 'total': 14},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4D2oVKAzLwOxOlBHhapW0l',
#     'id': '4D2oVKAzLwOxOlBHhapW0l',
#     'images': [],
#     'name': 'Btsoicy',
#     'popularity': 1,
#     'type': 'artist',
#     'uri': 'spotify:artist:4D2oVKAzLwOxOlBHhapW0l'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2KchnUtnAh5D87EFsiuGXX'},
#     'followers': {'href': None, 'total': 18},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2KchnUtnAh5D87EFsiuGXX',
#     'id': '2KchnUtnAh5D87EFsiuGXX',
#     'images': [],
#     'name': 'BTS Mula',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:2KchnUtnAh5D87EFsiuGXX'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4DbjSClsQ5pXUSSYmL7MIv'},
#     'followers': {'href': None, 'total': 877},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4DbjSClsQ5pXUSSYmL7MIv',
#     'id': '4DbjSClsQ5pXUSSYmL7MIv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c2b7c23db89d15c3882fbcca',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c2b7c23db89d15c3882fbcca',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c2b7c23db89d15c3882fbcca',
#       'width': 64}],
#     'name': 'BTswing',
#     'popularity': 2,
#     'type': 'artist',
#     'uri': 'spotify:artist:4DbjSClsQ5pXUSSYmL7MIv'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7ivYaz5Cg1dKlWaS7GaTrR'},
#     'followers': {'href': None, 'total': 24},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7ivYaz5Cg1dKlWaS7GaTrR',
#     'id': '7ivYaz5Cg1dKlWaS7GaTrR',
#     'images': [],
#     'name': 'Btsn',
#     'popularity': 3,
#     'type': 'artist',
#     'uri': 'spotify:artist:7ivYaz5Cg1dKlWaS7GaTrR'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Vbo3Mfxsk7yREJclu7XZ4'},
#     'followers': {'href': None, 'total': 307},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4Vbo3Mfxsk7yREJclu7XZ4',
#     'id': '4Vbo3Mfxsk7yREJclu7XZ4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731dc920c58e3110a23ee5f210',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021dc920c58e3110a23ee5f210',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511dc920c58e3110a23ee5f210',
#       'width': 64}],
#     'name': 'BTSQD',
#     'popularity': 7,
#     'type': 'artist',
#     'uri': 'spotify:artist:4Vbo3Mfxsk7yREJclu7XZ4'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/26c5B9yK2GiYUe8H7zPYny'},
#     'followers': {'href': None, 'total': 492},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/26c5B9yK2GiYUe8H7zPYny',
#     'id': '26c5B9yK2GiYUe8H7zPYny',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/bc896db6fc6fbcbc4c2e1fbaa33ff8551073a760',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/b4b272f8ced064305d5b84b476cd4a953148bac9',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/c2f56735e154e1e5573720c0f5363c8fa9a2bcd9',
#       'width': 160}],
#     'name': 'BTS Exclusive',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:26c5B9yK2GiYUe8H7zPYny'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7q40cWpll2cnzzA8KDGtLW'},
#     'followers': {'href': None, 'total': 33},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7q40cWpll2cnzzA8KDGtLW',
#     'id': '7q40cWpll2cnzzA8KDGtLW',
#     'images': [],
#     'name': 'BTS Jocco',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:7q40cWpll2cnzzA8KDGtLW'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6flS6SGmhIuT5klqLyA18T'},
#     'followers': {'href': None, 'total': 399},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6flS6SGmhIuT5klqLyA18T',
#     'id': '6flS6SGmhIuT5klqLyA18T',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273dc1d7af518f26d536f5f98a8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02dc1d7af518f26d536f5f98a8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851dc1d7af518f26d536f5f98a8',
#       'width': 64}],
#     'name': 'BTS Chitlom',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:6flS6SGmhIuT5klqLyA18T'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/57SrOZy1twEVXI7KVaIxyE'},
#     'followers': {'href': None, 'total': 205},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/57SrOZy1twEVXI7KVaIxyE',
#     'id': '57SrOZy1twEVXI7KVaIxyE',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27378f710d03c67a35e15f24b4e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0278f710d03c67a35e15f24b4e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485178f710d03c67a35e15f24b4e',
#       'width': 64}],
#     'name': 'Big Time Sarah And The BTS Express',
#     'popularity': 2,
#     'type': 'artist',
#     'uri': 'spotify:artist:57SrOZy1twEVXI7KVaIxyE'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1K8CHRPSbXdLzRfOwmT2Ee'},
#     'followers': {'href': None, 'total': 81},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1K8CHRPSbXdLzRfOwmT2Ee',
#     'id': '1K8CHRPSbXdLzRfOwmT2Ee',
#     'images': [],
#     'name': 'BTS & ALXS',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:1K8CHRPSbXdLzRfOwmT2Ee'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=BTS&type=artist&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 65}}

# %%
type(spotify.search("BTS", search_type = "artist"))
# Out:
# dict

# %%
bts_profile = spotify.search("BTS", search_type = "artist")["artists"]["items"][0]

# %%
bts_profile
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#  'followers': {'href': None, 'total': 18576005},
#  'genres': ['k-pop', 'k-pop boy group'],
#  'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#  'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/0c9057cb30520f9f883a220051260fc66a2f3ffa',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/34ee854082d0ea4d571e2ecf7f4aecea61270ad0',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/156147697b696d4a6180e037dc1e2a33117d8d4a',
#    'width': 160}],
#  'name': 'BTS',
#  'popularity': 93,
#  'type': 'artist',
#  'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}

# %%
bts_profile["followers"]["total"]
# Out:
# 18576005

# %%
spotify.get_album("6mJZTV8lCqnwftYZa94bXS")
# Out:
# {'href': 'https://api.spotify.com/v1/albums/6mJZTV8lCqnwftYZa94bXS/tracks?offset=0&limit=20',
#  'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#      'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#      'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#      'name': 'BTS',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 171023,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2BgZrbbAZxSnyE7U5efVrG'},
#    'href': 'https://api.spotify.com/v1/tracks/2BgZrbbAZxSnyE7U5efVrG',
#    'id': '2BgZrbbAZxSnyE7U5efVrG',
#    'is_local': False,
#    'name': 'Intro : Persona',
#    'preview_url': 'https://p.scdn.co/mp3-preview/cdb39e2a244c28523e6f34fc686a15251d2a03a6?cid=880e1efab91840d1839bc9e887302e4c',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2BgZrbbAZxSnyE7U5efVrG'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#      'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#      'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#      'name': 'BTS',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/26VFTg2z8YR0cCuwLzESi2'},
#      'href': 'https://api.spotify.com/v1/artists/26VFTg2z8YR0cCuwLzESi2',
#      'id': '26VFTg2z8YR0cCuwLzESi2',
#      'name': 'Halsey',
#      'type': 'artist',
#      'uri': 'spotify:artist:26VFTg2z8YR0cCuwLzESi2'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 229773,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1ZpFxOhpzT1MDCq7zjtOV1'},
#    'href': 'https://api.spotify.com/v1/tracks/1ZpFxOhpzT1MDCq7zjtOV1',
#    'id': '1ZpFxOhpzT1MDCq7zjtOV1',
#    'is_local': False,
#    'name': 'Boy With Luv (Feat. Halsey)',
#    'preview_url': 'https://p.scdn.co/mp3-preview/d16797fb391fb909f3c46454d7cf89a2718f8171?cid=880e1efab91840d1839bc9e887302e4c',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:1ZpFxOhpzT1MDCq7zjtOV1'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#      'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#      'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#      'name': 'BTS',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 226321,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1OqkHhYOcqfwYx7LqlAE8Y'},
#    'href': 'https://api.spotify.com/v1/tracks/1OqkHhYOcqfwYx7LqlAE8Y',
#    'id': '1OqkHhYOcqfwYx7LqlAE8Y',
#    'is_local': False,
#    'name': 'Make It Right',
#    'preview_url': 'https://p.scdn.co/mp3-preview/27d07e11fef56c0f8cb8a7e77a445e7371971ea5?cid=880e1efab91840d1839bc9e887302e4c',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:1OqkHhYOcqfwYx7LqlAE8Y'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#      'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#      'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#      'name': 'BTS',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 227275,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5oXdWFCLkBX5XmGbTrlK40'},
#    'href': 'https://api.spotify.com/v1/tracks/5oXdWFCLkBX5XmGbTrlK40',
#    'id': '5oXdWFCLkBX5XmGbTrlK40',
#    'is_local': False,
#    'name': 'Jamais Vu',
#    'preview_url': 'https://p.scdn.co/mp3-preview/698f1a4a1767f3ea64e40b04d9be33d923b8f827?cid=880e1efab91840d1839bc9e887302e4c',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:5oXdWFCLkBX5XmGbTrlK40'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#      'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#      'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#      'name': 'BTS',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 249215,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2SytGgja3g2R2N9lzV6n3E'},
#    'href': 'https://api.spotify.com/v1/tracks/2SytGgja3g2R2N9lzV6n3E',
#    'id': '2SytGgja3g2R2N9lzV6n3E',
#    'is_local': False,
#    'name': 'Dionysus',
#    'preview_url': 'https://p.scdn.co/mp3-preview/a862e818956230137be205f8d69aac014361f554?cid=880e1efab91840d1839bc9e887302e4c',
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:2SytGgja3g2R2N9lzV6n3E'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#      'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#      'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#      'name': 'BTS',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 259821,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2Nib4r0saYQf2pUV4RFDhl'},
#    'href': 'https://api.spotify.com/v1/tracks/2Nib4r0saYQf2pUV4RFDhl',
#    'id': '2Nib4r0saYQf2pUV4RFDhl',
#    'is_local': False,
#    'name': 'Interlude : Shadow',
#    'preview_url': 'https://p.scdn.co/mp3-preview/33c30046b75168bdcf63b405c2efff71c50a1a6e?cid=880e1efab91840d1839bc9e887302e4c',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:2Nib4r0saYQf2pUV4RFDhl'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#      'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#      'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#      'name': 'BTS',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 198260,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3bkkMZEAhx7rTVz1C0itRQ'},
#    'href': 'https://api.spotify.com/v1/tracks/3bkkMZEAhx7rTVz1C0itRQ',
#    'id': '3bkkMZEAhx7rTVz1C0itRQ',
#    'is_local': False,
#    'name': 'Black Swan',
#    'preview_url': 'https://p.scdn.co/mp3-preview/879c7106422b0b53852209da6a63210be7e09b01?cid=880e1efab91840d1839bc9e887302e4c',
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:3bkkMZEAhx7rTVz1C0itRQ'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#      'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#      'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#      'name': 'BTS',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 180220,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0ono6UCNVZ1XqOm6j78Blu'},
#    'href': 'https://api.spotify.com/v1/tracks/0ono6UCNVZ1XqOm6j78Blu',
#    'id': '0ono6UCNVZ1XqOm6j78Blu',
#    'is_local': False,
#    'name': 'Filter',
#    'preview_url': 'https://p.scdn.co/mp3-preview/43c93d00d5efbf03937c1ca807fdb383399d598b?cid=880e1efab91840d1839bc9e887302e4c',
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:0ono6UCNVZ1XqOm6j78Blu'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#      'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#      'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#      'name': 'BTS',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 234457,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4vTgx6h4seHvkuFh84JXYP'},
#    'href': 'https://api.spotify.com/v1/tracks/4vTgx6h4seHvkuFh84JXYP',
#    'id': '4vTgx6h4seHvkuFh84JXYP',
#    'is_local': False,
#    'name': 'My Time',
#    'preview_url': 'https://p.scdn.co/mp3-preview/67513befcc0aea1b35469beace63730a10c506dd?cid=880e1efab91840d1839bc9e887302e4c',
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:4vTgx6h4seHvkuFh84JXYP'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#      'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#      'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#      'name': 'BTS',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 217404,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3op7HNwLli54MBjFGzIlZO'},
#    'href': 'https://api.spotify.com/v1/tracks/3op7HNwLli54MBjFGzIlZO',
#    'id': '3op7HNwLli54MBjFGzIlZO',
#    'is_local': False,
#    'name': 'Louder than bombs',
#    'preview_url': 'https://p.scdn.co/mp3-preview/c6e50ef39b6a32414e5f6d1f7996951452f936b0?cid=880e1efab91840d1839bc9e887302e4c',
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:3op7HNwLli54MBjFGzIlZO'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#      'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#      'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#      'name': 'BTS',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 246380,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2QyuXBcV1LJ2rq01KhreMF'},
#    'href': 'https://api.spotify.com/v1/tracks/2QyuXBcV1LJ2rq01KhreMF',
#    'id': '2QyuXBcV1LJ2rq01KhreMF',
#    'is_local': False,
#    'name': 'ON',
#    'preview_url': 'https://p.scdn.co/mp3-preview/1a6af8c9cbcb74c83baabaa10f454db08c13e178?cid=880e1efab91840d1839bc9e887302e4c',
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:2QyuXBcV1LJ2rq01KhreMF'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#      'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#      'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#      'name': 'BTS',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 225012,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1aKuG1GG76xPLUkjBbQo3W'},
#    'href': 'https://api.spotify.com/v1/tracks/1aKuG1GG76xPLUkjBbQo3W',
#    'id': '1aKuG1GG76xPLUkjBbQo3W',
#    'is_local': False,
#    'name': 'UGH!',
#    'preview_url': 'https://p.scdn.co/mp3-preview/fd37160449b3c6a8f273fb5e4a01626f7a226c25?cid=880e1efab91840d1839bc9e887302e4c',
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:1aKuG1GG76xPLUkjBbQo3W'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#      'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#      'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#      'name': 'BTS',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 250295,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4AlihYDqxXshKhvh5tnMfP'},
#    'href': 'https://api.spotify.com/v1/tracks/4AlihYDqxXshKhvh5tnMfP',
#    'id': '4AlihYDqxXshKhvh5tnMfP',
#    'is_local': False,
#    'name': '00:00 (Zero O’Clock)',
#    'preview_url': 'https://p.scdn.co/mp3-preview/c99f9536de8a5d40e925a4fe5cccea03a1af419b?cid=880e1efab91840d1839bc9e887302e4c',
#    'track_number': 13,
#    'type': 'track',
#    'uri': 'spotify:track:4AlihYDqxXshKhvh5tnMfP'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#      'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#      'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#      'name': 'BTS',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 233265,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4BKOjYosPhw334moS3wlbO'},
#    'href': 'https://api.spotify.com/v1/tracks/4BKOjYosPhw334moS3wlbO',
#    'id': '4BKOjYosPhw334moS3wlbO',
#    'is_local': False,
#    'name': 'Inner Child',
#    'preview_url': 'https://p.scdn.co/mp3-preview/c81decec9e9bd8aabe6f3c7f2799ed2e4025470e?cid=880e1efab91840d1839bc9e887302e4c',
#    'track_number': 14,
#    'type': 'track',
#    'uri': 'spotify:track:4BKOjYosPhw334moS3wlbO'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#      'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#      'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#      'name': 'BTS',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 199338,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7w05lsU2VLSeiT8Nukrv5M'},
#    'href': 'https://api.spotify.com/v1/tracks/7w05lsU2VLSeiT8Nukrv5M',
#    'id': '7w05lsU2VLSeiT8Nukrv5M',
#    'is_local': False,
#    'name': 'Friends',
#    'preview_url': 'https://p.scdn.co/mp3-preview/7011f2ff7f8f70782ba04e357aa1bff42ee20007?cid=880e1efab91840d1839bc9e887302e4c',
#    'track_number': 15,
#    'type': 'track',
#    'uri': 'spotify:track:7w05lsU2VLSeiT8Nukrv5M'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#      'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#      'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#      'name': 'BTS',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 208589,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1xfXXujIlLZAx5wpu46Nyk'},
#    'href': 'https://api.spotify.com/v1/tracks/1xfXXujIlLZAx5wpu46Nyk',
#    'id': '1xfXXujIlLZAx5wpu46Nyk',
#    'is_local': False,
#    'name': 'Moon',
#    'preview_url': 'https://p.scdn.co/mp3-preview/f4d1590859b7157d448b9b2bdaa73b1f8cefa477?cid=880e1efab91840d1839bc9e887302e4c',
#    'track_number': 16,
#    'type': 'track',
#    'uri': 'spotify:track:1xfXXujIlLZAx5wpu46Nyk'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#      'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#      'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#      'name': 'BTS',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 237540,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/37TSJmYKLxXmx8OehFpqMN'},
#    'href': 'https://api.spotify.com/v1/tracks/37TSJmYKLxXmx8OehFpqMN',
#    'id': '37TSJmYKLxXmx8OehFpqMN',
#    'is_local': False,
#    'name': 'Respect',
#    'preview_url': 'https://p.scdn.co/mp3-preview/92072fff00e62636917c31592c9df176d55fa9ae?cid=880e1efab91840d1839bc9e887302e4c',
#    'track_number': 17,
#    'type': 'track',
#    'uri': 'spotify:track:37TSJmYKLxXmx8OehFpqMN'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#      'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#      'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#      'name': 'BTS',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 261542,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/44WLOqH7QayQOQdeUHeKUK'},
#    'href': 'https://api.spotify.com/v1/tracks/44WLOqH7QayQOQdeUHeKUK',
#    'id': '44WLOqH7QayQOQdeUHeKUK',
#    'is_local': False,
#    'name': 'We are Bulletproof : the Eternal',
#    'preview_url': 'https://p.scdn.co/mp3-preview/88aeb9a27fae72fd1b7d28ae769e23139637df5a?cid=880e1efab91840d1839bc9e887302e4c',
#    'track_number': 18,
#    'type': 'track',
#    'uri': 'spotify:track:44WLOqH7QayQOQdeUHeKUK'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#      'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#      'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#      'name': 'BTS',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 196198,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3r9FFjLrAIQjoR8pSHVPC9'},
#    'href': 'https://api.spotify.com/v1/tracks/3r9FFjLrAIQjoR8pSHVPC9',
#    'id': '3r9FFjLrAIQjoR8pSHVPC9',
#    'is_local': False,
#    'name': 'Outro : Ego',
#    'preview_url': 'https://p.scdn.co/mp3-preview/396c860a6dcf98c94c0b371da7f3afa2e83341fa?cid=880e1efab91840d1839bc9e887302e4c',
#    'track_number': 19,
#    'type': 'track',
#    'uri': 'spotify:track:3r9FFjLrAIQjoR8pSHVPC9'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#      'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#      'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#      'name': 'BTS',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5WUlDfRSoLAfcVSX1WnrxN'},
#      'href': 'https://api.spotify.com/v1/artists/5WUlDfRSoLAfcVSX1WnrxN',
#      'id': '5WUlDfRSoLAfcVSX1WnrxN',
#      'name': 'Sia',
#      'type': 'artist',
#      'uri': 'spotify:artist:5WUlDfRSoLAfcVSX1WnrxN'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 246816,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3IB5qOeMayvpOdHxYCL5tZ'},
#    'href': 'https://api.spotify.com/v1/tracks/3IB5qOeMayvpOdHxYCL5tZ',
#    'id': '3IB5qOeMayvpOdHxYCL5tZ',
#    'is_local': False,
#    'name': 'ON (Feat. Sia)',
#    'preview_url': 'https://p.scdn.co/mp3-preview/00b8c392f241849438956590f4b90ea432f68cec?cid=880e1efab91840d1839bc9e887302e4c',
#    'track_number': 20,
#    'type': 'track',
#    'uri': 'spotify:track:3IB5qOeMayvpOdHxYCL5tZ'}],
#  'limit': 20,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 20}
